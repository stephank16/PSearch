# %% [markdown]
# # Browsing the DKRZ data pool using solr and Pandas Dataframes
#
# - copy the file dkrz_pool_solr.py to the home directory of this notebook
# - specify a dictionary ("search_dict" below) with your search facets
#     - possible facet values are:  project, product, institute, model, experiment, time_frequency, realm, variable, ensemble, cmor_table, grid
# - call the df_search function with your seach dictionary, the max number of entries to return as well as an additional list of facets to include in the result se

# %%
search_dict= {'project':'cmip6',
            'variable':'tas'
           }

from dkrz_pool_solr import df_search, file_pattern, dir_pattern

dfr = df_search(search_dict,10,['mip_era','activity','institution','version','lfile'])
dfr
# Out:
# http://cmip-eval.dkrz.de:8983/solr/files/select?q=*:*&fq=project:cmip6+AND+variable:tas&rows=10&wt=python
# 6004 files found  --  10 files included in result
#       activity   experiment  \
# 0  ScenarioMIP       ssp585
# 1  ScenarioMIP  ssp534-over
# 2  ScenarioMIP       ssp460
# 3  ScenarioMIP       ssp434
# 4  ScenarioMIP       ssp370
# 5  ScenarioMIP       ssp245
# 6  ScenarioMIP       ssp245
# 7  ScenarioMIP       ssp245
# 8  ScenarioMIP       ssp245
# 9  ScenarioMIP       ssp245
#
#                                                 file grid institution  \
# 0  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp585/r1i1p1...   gn         MRI
# 1  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp534-over/r...   gn         MRI
# 2  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp460/r1i1p1...   gn         MRI
# 3  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp434/r1i1p1...   gn         MRI
# 4  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp370/r1i1p1...   gn         MRI
# 5  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp245/r5i1p1...   gn         MRI
# 6  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp245/r4i1p1...   gn         MRI
# 7  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp245/r3i1p1...   gn         MRI
# 8  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp245/r2i1p1...   gn         MRI
# 9  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp245/r1i1p1...   gn         MRI
#
#                                                lfile    member mip_era  \
# 0  tas_Amon_MRI-ESM2-0_ssp585_r1i1p1f1_gn_201501-...  r1i1p1f1   CMIP6
# 1  tas_Amon_MRI-ESM2-0_ssp534-over_r1i1p1f1_gn_20...  r1i1p1f1   CMIP6
# 2  tas_Amon_MRI-ESM2-0_ssp460_r1i1p1f1_gn_201501-...  r1i1p1f1   CMIP6
# 3  tas_Amon_MRI-ESM2-0_ssp434_r1i1p1f1_gn_201501-...  r1i1p1f1   CMIP6
# 4  tas_Amon_MRI-ESM2-0_ssp370_r1i1p1f1_gn_201501-...  r1i1p1f1   CMIP6
# 5  tas_Amon_MRI-ESM2-0_ssp245_r5i1p1f1_gn_201501-...  r5i1p1f1   CMIP6
# 6  tas_Amon_MRI-ESM2-0_ssp245_r4i1p1f1_gn_201501-...  r4i1p1f1   CMIP6
# 7  tas_Amon_MRI-ESM2-0_ssp245_r3i1p1f1_gn_201501-...  r3i1p1f1   CMIP6
# 8  tas_Amon_MRI-ESM2-0_ssp245_r2i1p1f1_gn_201501-...  r2i1p1f1   CMIP6
# 9  tas_Amon_MRI-ESM2-0_ssp245_r1i1p1f1_gn_201501-...  r1i1p1f1   CMIP6
#
#         model table           time variable    version
# 0  MRI-ESM2-0  Amon  201501-210012      tas  v20190222
# 1  MRI-ESM2-0  Amon  204001-210012      tas  v20190222
# 2  MRI-ESM2-0  Amon  201501-210012      tas  v20190222
# 3  MRI-ESM2-0  Amon  201501-210012      tas  v20190222
# 4  MRI-ESM2-0  Amon  201501-210012      tas  v20190222
# 5  MRI-ESM2-0  Amon  201501-203012      tas  v20190308
# 6  MRI-ESM2-0  Amon  201501-203012      tas  v20190308
# 7  MRI-ESM2-0  Amon  201501-203012      tas  v20190308
# 8  MRI-ESM2-0  Amon  201501-203012      tas  v20190308
# 9  MRI-ESM2-0  Amon  201501-210012      tas  v20190222

# %%
efr = dfr.loc[dfr['experiment']=='ssp585']
efr
# Out:
#       activity experiment                                               file  \
# 0  ScenarioMIP     ssp585  CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp585/r1i1p1...
#
#   grid institution                                              lfile  \
# 0   gn         MRI  tas_Amon_MRI-ESM2-0_ssp585_r1i1p1f1_gn_201501-...
#
#      member mip_era       model table           time variable    version
# 0  r1i1p1f1   CMIP6  MRI-ESM2-0  Amon  201501-210012      tas  v20190222

# %%
ffr = dfr[file_pattern['CMIP6']]
ffr
# Out:
#   variable table       model   experiment    member grid           time
# 0      tas  Amon  MRI-ESM2-0       ssp585  r1i1p1f1   gn  201501-210012
# 1      tas  Amon  MRI-ESM2-0  ssp534-over  r1i1p1f1   gn  204001-210012
# 2      tas  Amon  MRI-ESM2-0       ssp460  r1i1p1f1   gn  201501-210012
# 3      tas  Amon  MRI-ESM2-0       ssp434  r1i1p1f1   gn  201501-210012
# 4      tas  Amon  MRI-ESM2-0       ssp370  r1i1p1f1   gn  201501-210012
# 5      tas  Amon  MRI-ESM2-0       ssp245  r5i1p1f1   gn  201501-203012
# 6      tas  Amon  MRI-ESM2-0       ssp245  r4i1p1f1   gn  201501-203012
# 7      tas  Amon  MRI-ESM2-0       ssp245  r3i1p1f1   gn  201501-203012
# 8      tas  Amon  MRI-ESM2-0       ssp245  r2i1p1f1   gn  201501-203012
# 9      tas  Amon  MRI-ESM2-0       ssp245  r1i1p1f1   gn  201501-210012

# %%
ggr = dfr[dir_pattern['CMIP6']]
ggr
# Out:
#   mip_era     activity institution       model   experiment    member table  \
# 0   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp585  r1i1p1f1  Amon
# 1   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0  ssp534-over  r1i1p1f1  Amon
# 2   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp460  r1i1p1f1  Amon
# 3   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp434  r1i1p1f1  Amon
# 4   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp370  r1i1p1f1  Amon
# 5   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp245  r5i1p1f1  Amon
# 6   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp245  r4i1p1f1  Amon
# 7   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp245  r3i1p1f1  Amon
# 8   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp245  r2i1p1f1  Amon
# 9   CMIP6  ScenarioMIP         MRI  MRI-ESM2-0       ssp245  r1i1p1f1  Amon
#
#   variable grid    version                                              lfile
# 0      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp585_r1i1p1f1_gn_201501-...
# 1      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp534-over_r1i1p1f1_gn_20...
# 2      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp460_r1i1p1f1_gn_201501-...
# 3      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp434_r1i1p1f1_gn_201501-...
# 4      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp370_r1i1p1f1_gn_201501-...
# 5      tas   gn  v20190308  tas_Amon_MRI-ESM2-0_ssp245_r5i1p1f1_gn_201501-...
# 6      tas   gn  v20190308  tas_Amon_MRI-ESM2-0_ssp245_r4i1p1f1_gn_201501-...
# 7      tas   gn  v20190308  tas_Amon_MRI-ESM2-0_ssp245_r3i1p1f1_gn_201501-...
# 8      tas   gn  v20190308  tas_Amon_MRI-ESM2-0_ssp245_r2i1p1f1_gn_201501-...
# 9      tas   gn  v20190222  tas_Amon_MRI-ESM2-0_ssp245_r1i1p1f1_gn_201501-...
